# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/ageron/handson-ml3/blob/main/tools_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
#   <td>
#     <a target="_blank" href="https://kaggle.com/kernels/welcome?src=https://github.com/ageron/handson-ml3/blob/main/tools_numpy.ipynb"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" /></a>
#   </td>
# </table>

# %% [markdown]
# A continuación te presento el **diseño completo de la Clase 3**, **alineado institucionalmente**, pero **reformulada estratégicamente para posicionar a Python como alternativa de código abierto a Stata**,
# * **sin perder la lógica, sintaxis mental ni potencia analítica** que los estudiantes deben aprender para “ir y venir” entre softwares, tal como lo planteas en el seminario.

# %% [markdown]
# He mantenido **la misma estructura conceptual de Stata**, pero mostrando **el equivalente funcional en Python**, lo cual es pedagógicamente muy potente para estudiantes de ciencias sociales.
#
# ---

# %% [markdown]
# # **Clase 3 – 23 de diciembre de 2026**

# %% [markdown]
# ## **Análisis descriptivo con Python (alternativa abierta a Stata)**
#
# ---

# %% [markdown]
# # 1. Propósito formativo de la clase

# %% [markdown]
# Que el estudiante:
#
# * Comprenda que **Python puede realizar las mismas tareas de análisis descriptivo que Stata**
# * Identifique **equivalencias funcionales** entre comandos de Stata y librerías de Python
# * Desarrolle habilidades para:
#
#   * Analizar variables categóricas y cuantitativas
#   * Construir y recodificar variables
#   * Etiquetar categorías de análisis
# * Fortalezca la idea de **lenguajes como herramientas intercambiables**, no como fines en sí mismos
#
# ---

# %% [markdown]
# ## 2. Introducción conceptual: Stata vs Python

# %% [markdown]
# # Idea clave para los estudiantes

# %% [markdown]
# > Stata es un software cerrado con comandos especializados.
# > Python es un lenguaje abierto que, mediante librerías, reproduce y amplía esas funcionalidades.

# %% [markdown]
# | Tarea        | Stata              | Python                |
# | ------------ | ------------------ | --------------------- |
# | Abrir base   | `use encuesta.dta` | `pd.read_stata()`     |
# | Frecuencias  | `tab`              | `value_counts()`      |
# | Descriptivos | `summarize`        | `.describe()`         |
# | Recodificar  | `recode`           | `map()`, `np.where()` |
# | Etiquetar    | `label define`     | `CategoricalDtype`    |
#
# ---

# %% [markdown]
# ## 3. Introducción al “entorno Python” para análisis descriptivo

# %% [markdown]
# ### Librerías centrales

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# * `pandas` → manejo de datos (equivalente a la lógica de Stata)
# * `numpy` → operaciones vectorizadas (motor matemático)

# %% [markdown]
# # **Mensaje didáctico**:

# %% [markdown]
# > En Python, no hay “comandos sueltos”; todo opera sobre objetos (DataFrames y Series).
#
# ---

# %% [markdown]
# # Generación del dataframe de ejemplo para todo la clase 3
#
# Perfecto, Marco. A continuación te entrego un **script de Python cuidadosamente diseñado para la Clase 3**, que **genera artificialmente un DataFrame de encuesta** con **todas las variables necesarias** para realizar **cada una de las actividades de análisis descriptivo** planteadas (categóricas, cuantitativas, recodificación, cohortes, desigualdad).
#
# Este DataFrame está pensado **pedagógicamente**, no solo técnicamente, y reproduce **estructuras típicas de encuestas sociales reales**.
#
# ---
#
# # 📊 Script de Python – DataFrame de encuesta (Clase 3)
#
# 👉 **Ejecutar en Jupyter / Google Colab**
#
# ```python

# %%
import pandas as pd
import numpy as np

# --------------------------------------------------
# 1. Reproducibilidad
# --------------------------------------------------
np.random.seed(123)

# --------------------------------------------------
# 2. Tamaño de la muestra
# --------------------------------------------------
n = 200

# --------------------------------------------------
# 3. Generación del DataFrame
# --------------------------------------------------

df = pd.DataFrame({

    # Identificador
    "id": range(1, n + 1),

    # Edad
    "edad": np.random.randint(18, 66, size=n),

    # Género
    # 1 = Mujer, 2 = Hombre
    "genero": np.random.choice([1, 2], size=n, p=[0.53, 0.47]),

    # Nivel educativo (ordinal)
    # 1 = Primaria
    # 2 = Secundaria
    # 3 = Técnica
    # 4 = Universitaria
    "educacion": np.random.choice(
        [1, 2, 3, 4],
        size=n,
        p=[0.28, 0.34, 0.18, 0.20]
    ),

    # Clase social
    # 1 = Baja, 2 = Media, 3 = Alta
    "clase_social": np.random.choice(
        [1, 2, 3],
        size=n,
        p=[0.42, 0.43, 0.15]
    ),

    # Origen étnico
    # 1 = No étnico, 2 = Indígena, 3 = Afrodescendiente
    "origen_etnico": np.random.choice(
        [1, 2, 3],
        size=n,
        p=[0.70, 0.12, 0.18]
    ),

    # Condición de ocupación
    # 1 = Ocupado, 0 = No ocupado
    "ocupado": np.random.choice([0, 1], size=n, p=[0.28, 0.72])
})

# --------------------------------------------------
# 4. Ingreso: variable clave de desigualdad
#    Dependiente de educación, clase y género
# --------------------------------------------------

ingreso_base = 800000
efecto_educacion = df["educacion"] * 600000
efecto_clase = df["clase_social"] * 700000
penalizacion_genero = np.where(df["genero"] == 1, -300000, 0)

ruido = np.random.normal(0, 400000, size=n)

df["ingreso"] = (
    ingreso_base
    + efecto_educacion
    + efecto_clase
    + penalizacion_genero
    + ruido
).astype(int)

# Asegurar ingresos positivos
df["ingreso"] = df["ingreso"].clip(lower=600000)

# --------------------------------------------------
# 5. Etiquetado como variables categóricas (CORREGIDO)
# --------------------------------------------------

df["genero"] = df["genero"].astype("category")
df["genero"] = df["genero"].cat.rename_categories(
    ["Mujer", "Hombre"]
)

df["educacion"] = df["educacion"].astype("category")
df["educacion"] = df["educacion"].cat.rename_categories(
    ["Primaria", "Secundaria", "Técnica", "Universitaria"]
)

df["clase_social"] = df["clase_social"].astype("category")
df["clase_social"] = df["clase_social"].cat.rename_categories(
    ["Baja", "Media", "Alta"]
)

df["origen_etnico"] = df["origen_etnico"].astype("category")
df["origen_etnico"] = df["origen_etnico"].cat.rename_categories(
    ["No étnico", "Indígena", "Afrodescendiente"]
)

df["ocupado"] = df["ocupado"].astype("category")
df["ocupado"] = df["ocupado"].cat.rename_categories(
    ["No ocupado", "Ocupado"]
)

# --------------------------------------------------
# 6. Vista previa
# --------------------------------------------------
df.head()
# Out:
#    id  edad  genero      educacion clase_social     origen_etnico     ocupado  \
# 0   1    63  Hombre     Secundaria         Baja         No étnico  No ocupado
# 1   2    20   Mujer  Universitaria         Baja  Afrodescendiente     Ocupado
# 2   3    46   Mujer     Secundaria        Media         No étnico     Ocupado
# 3   4    52  Hombre     Secundaria         Baja         No étnico     Ocupado
# 4   5    56  Hombre     Secundaria         Baja         No étnico     Ocupado
#
#    ingreso
# 0  1744614
# 1  4413152
# 2  3409845
# 3  2855705
# 4  2989126

# %% [markdown]
# # ¿Qué permite hacer este DataFrame en la Clase 3?

# %% [markdown]
# ✔️ Frecuencias y porcentajes
# ✔️ Tablas de contingencia
# ✔️ Medidas descriptivas
# ✔️ Recodificación
# ✔️ Construcción de cohortes
# ✔️ Lectura sociológica de desigualdades
# ✔️ Preparación para regresión (clases 5–8)
#
# ---

# %% [markdown]
# ## 🧠 Ejercicios que encajan perfectamente
#
# ```python
# df["clase_social"].value_counts(normalize=True) * 100
# df["ingreso"].describe()
# pd.crosstab(df["genero"], df["clase_social"])
# ```
#
# ---
#
# ## 🎓 Valor pedagógico
#
# * Dataset **realista**
# * Brechas incorporadas explícitamente
# * Decisiones teóricas visibles en el código
# * Ideal para comparar con Stata línea por línea
#
# ---
#
# ## 🔜 Siguientes pasos naturales
#
# Si quieres, puedo:
#
# * 📓 Guardar este DataFrame como `encuesta_clase3.dta`
# * 📊 Preparar un **laboratorio guiado** con preguntas
# * 🤖 Integrar prompts de IA para que el estudiante “dialogue” con el código
#
# Dime cómo deseas continuar y lo armamos.

# %% [markdown]
# ## 4. Variables categóricas y cuantitativas

# %% [markdown]
# ### Identificación de tipos de variables

# %%
df.info()

# %% [markdown]
# Discusión:
#
# * Variables `int` y `float` → cuantitativas
# * Variables `object` o `category` → categóricas
#
# ---

# %% [markdown]
# ## 5. Análisis de variables categóricas

# %% [markdown]
# *(Equivalente a `tab` en Stata)*
#
# ### Frecuencias absolutas

# %%
df["clase_social"].value_counts()

# %% [markdown]
# ## Frecuencias relativas (porcentajes)

# %%
df["clase_social"].value_counts(normalize=True) * 100

# %% [markdown]
# # Comparación directa con Stata:

# %% [markdown]
# ```stata
# tab clase_social
# ```

# %% [markdown]
# ### Actividad 1 (individual)
#
# * Calcular frecuencias y porcentajes de:
#
#   * `genero`
#   * `ocupado`
# * Interpretar sociológicamente los resultados
#
# ---

# %% [markdown]
# ## 6. Análisis de variables cuantitativas
#
# *(Equivalente a `summarize` en Stata)*

# %% [markdown]
# ### Descriptivos básicos

# %%
df["ingreso"].describe()

# %% [markdown]
# Incluye:
#
# * media
# * desviación estándar
# * mínimo y máximo
# * cuartiles
#
# 📌 Equivalente Stata:
#
# ```stata
# summarize ingreso
# ```
#
# ---

# %% [markdown]
# ### Actividad 2 (guiada)
#
# * Comparar media y mediana del ingreso
# * Discutir:
#
#   > ¿Qué indica una diferencia grande entre media y mediana en estudios de desigualdad?
#
# ---

# %% [markdown]
# ## 7. Construcción de variables complejas
#
# ### Ejemplo: cohorte etaria

# %%
df["cohorte_edad"] = pd.cut(
    df["edad"],
    bins=[18, 29, 44, 64],
    labels=["18-29", "30-44", "45-64"]
)

# %% [markdown]
# 📌 Equivalente conceptual en Stata:
#
# ```stata
# recode edad (18/29=1) (30/44=2) (45/64=3), gen(cohorte)
# ```
#
# ---
#
# ### Actividad 3 (parejas)
#
# * Crear una variable de edad en 4 grupos
# * Comparar distribución por género
#
# ---
#
# ## 8. Recategorización de variables
#
# ### Ejemplo: educación baja / media / alta
#
# ```python
# map_educ = {
#     1: "Baja",
#     2: "Media",
#     3: "Media",
#     4: "Alta"
# }
#
# df["educacion_rec"] = df["educacion"].map(map_educ)
# ```
#
# 📌 Discusión metodológica:
#
# > Recategorizar es una decisión teórica, no solo técnica.
#
# ---
#
# ## 9. Etiquetado de variables y categorías
#
# ### Uso de variables categóricas con etiquetas
#
# ```python
# df["clase_social"] = df["clase_social"].astype("category")
# df["clase_social"].cat.rename_categories(
#     ["Baja", "Media", "Alta"],
#     inplace=True
# )
# ```

# %% [markdown]
# 📌 Equivalente Stata:
#
# ```stata
# label define clase 1 "Baja" 2 "Media" 3 "Alta"
# label values clase_social clase
# ```
#
# ---

# %% [markdown]
# ## 10. Actividad integradora (grupal)
#
# ### Mini-laboratorio
#
# Cada grupo debe:
#
# 1. Seleccionar una variable de desigualdad
# 2. Describirla (frecuencias o descriptivos)
# 3. Recodificarla
# 4. Justificar teóricamente la decisión
#
# 📤 Entrega:
#
# * Notebook (`.ipynb`)
# * Interpretación escrita (máx. 1 página)
#
# ---
#
# ## 11. Cierre conceptual de la clase
#
# Mensaje clave:
#
# > Python no reemplaza a Stata:
# > **lo amplía, lo complementa y lo hace reproducible**.
#
# * Código abierto
# * Integración con IA
# * Transparencia metodológica
# * Reproducibilidad científica
#
# ---

# %% [markdown]
# ## 12. Preparación para la Clase 4
#
# * Leer sobre esquemas de clases sociales
# * Pensar:
#
#   > ¿Cómo se “construye” una clase social desde datos?
#
# ---

# %% [markdown]
# Si quieres, en el siguiente mensaje puedo:
#
# * 📓 Convertir esta clase en **cuaderno Jupyter listo para GitHub**
# * 🧪 Diseñar la **rúbrica de evaluación**
# * 🔄 Armar una **tabla Stata ↔ Python** para entregar a estudiantes
#
# Tú decides cómo seguimos.

# %% [markdown]
# A continuación te entrego **dos insumos institucionales clave**, coherentes con el enfoque metodológico del curso y muy útiles para los estudiantes:

# %% [markdown]
# 1. ✅ **Rúbrica de evaluación de la Clase 3**
# 2. 🔄 **Tabla de correspondencia STATA ↔ PYTHON** (pensada como material de estudio)

# %% [markdown]
# Ambos están diseñados para **reforzar la idea de equivalencia conceptual entre softwares**, no la memorización de comandos.
#
# ---

# %% [markdown]
# # 1. RÚBRICA DE EVALUACIÓN – CLASE 3
#
# ## *Análisis descriptivo con Python (alternativa a Stata)*
#
# ### Producto evaluado
#
# Cuaderno Jupyter (`.ipynb`) + interpretación escrita breve
#
# ---

# %% [markdown]
# # Competencia evaluada
#
# > Analiza descriptivamente variables de estratificación social utilizando Python, justificando decisiones metodológicas y estableciendo equivalencias funcionales con Stata.
#
# ---

# %% [markdown]
# # Rúbrica (escala 1–5)

# %% [markdown]
# | Criterio                                   | 5 – Excelente                                                             | 4 – Bueno                                      | 3 – Aceptable                   | 2 – Insuficiente           |
# | ------------------------------------------ | ------------------------------------------------------------------------- | ---------------------------------------------- | ------------------------------- | -------------------------- |
# | **Carga y exploración del dataset**        | Carga correcta, uso de `.info()` y revisión crítica de tipos de variables | Carga correcta con exploración básica          | Carga correcta sin exploración  | Errores en carga o lectura |
# | **Análisis de variables categóricas**      | Frecuencias y porcentajes bien calculados e interpretados                 | Frecuencias correctas, interpretación limitada | Solo frecuencias sin análisis   | Análisis incorrecto        |
# | **Análisis de variables cuantitativas**    | Uso adecuado de descriptivos e interpretación sociológica                 | Descriptivos correctos, interpretación parcial | Descriptivos sin interpretación | Uso incorrecto             |
# | **Construcción de variables complejas**    | Variable bien construida y justificada teóricamente                       | Variable correcta con justificación mínima     | Variable técnica sin reflexión  | Variable mal construida    |
# | **Recategorización y etiquetado**          | Recodificación clara y coherente con etiquetas                            | Recodificación correcta sin etiquetas          | Recodificación poco clara       | Errores conceptuales       |
# | **Equivalencia Stata–Python**              | Explicita y reflexiona equivalencias                                      | Menciona equivalencias                         | Equivalencias implícitas        | No reconoce equivalencias  |
# | **Claridad del código y reproducibilidad** | Código ordenado, comentado y reproducible                                 | Código funcional con pocos comentarios         | Código poco claro               | Código no funcional        |
#
# ---

# %% [markdown]
# # Calificación sugerida
#
# * Promedio de criterios
# * Peso sugerido Clase 3: **10% del curso**
# * Retroalimentación cualitativa obligatoria
#
# ---

# %% [markdown]
# # Criterio transversal (no numérico)
#
# > El estudiante comprende que las decisiones estadísticas son **teóricas y sociales**, no solo técnicas.
#
# ---

# %% [markdown]
# # 2. TABLA DE CORRESPONDENCIA STATA ↔ PYTHON

# %% [markdown]
# ## *Análisis descriptivo y construcción de variables*
#
# ---

# %% [markdown]
# # Gestión de datos
#
# | Tarea              | STATA                     | PYTHON                          |
# | ------------------ | ------------------------- | ------------------------------- |
# | Abrir base         | `use encuesta.dta, clear` | `pd.read_stata("encuesta.dta")` |
# | Guardar base       | `save encuesta.dta`       | `df.to_stata("encuesta.dta")`   |
# | Ver estructura     | `describe`                | `df.info()`                     |
# | Ver primeras filas | `list in 1/5`             | `df.head()`                     |
#
# ---

# %% [markdown]
# # Variables categóricas
#
# | Análisis        | STATA                     | PYTHON                         |
# | --------------- | ------------------------- | ------------------------------ |
# | Frecuencias     | `tab genero`              | `df["genero"].value_counts()`  |
# | Porcentajes     | `tab genero, col`         | `value_counts(normalize=True)` |
# | Tablas cruzadas | `tab genero clase_social` | `pd.crosstab()`                |
#
# ---

# %% [markdown]
# # Variables cuantitativas
#
# | Análisis            | STATA               | PYTHON                     |
# | ------------------- | ------------------- | -------------------------- |
# | Descriptivos        | `summarize ingreso` | `df["ingreso"].describe()` |
# | Media               | `mean ingreso`      | `df["ingreso"].mean()`     |
# | Mediana             | `median ingreso`    | `df["ingreso"].median()`   |
# | Desviación estándar | `sd ingreso`        | `df["ingreso"].std()`      |
#
# ---

# %% [markdown]
# # Construcción y recodificación de variables
#
# | Tarea          | STATA                | PYTHON                 |
# | -------------- | -------------------- | ---------------------- |
# | Crear variable | `gen nueva = ...`    | `df["nueva"] = ...`    |
# | Recodificar    | `recode edad (...)`  | `np.where()` / `map()` |
# | Agrupar        | `egen grupo = cut()` | `pd.cut()`             |
#
# ---

# %% [markdown]
# # Etiquetado
#
# | Tarea             | STATA          | PYTHON                     |
# | ----------------- | -------------- | -------------------------- |
# | Definir etiquetas | `label define` | `CategoricalDtype`         |
# | Asignar etiquetas | `label values` | `.cat.rename_categories()` |
#
# ---

# %% [markdown]
# # Mensaje pedagógico final para estudiantes
#
# > Aprender Stata o Python no es aprender comandos,
# > es aprender **a pensar con datos**.

# %% [markdown]
# > Un buen analista puede cambiar de software
# > sin cambiar de marco teórico.
#
# ---

# %% [markdown]
# Si quieres, el siguiente paso natural sería:

# %% [markdown]
# * **Clase 4**: construcción empírica de clases sociales (Stata + Python)
# * Diseñar una **evaluación comparativa** Python vs Stata
# * Integrar **uso explícito de IA** como asistente metodológico
#
# Dime cómo deseas continuar.
